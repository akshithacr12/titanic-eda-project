# %% [markdown]
# # 🛳️ Titanic EDA Project
#
# A beginner-friendly exploratory data analysis on the Titanic dataset to uncover patterns behind passenger survival.

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading dataset

# %%
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
df = pd.read_csv(url)
df.head()
